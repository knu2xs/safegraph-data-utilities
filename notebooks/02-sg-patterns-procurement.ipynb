# %%
from gzip import GzipFile
from io import BytesIO
import importlib
import os
from pathlib import Path
import shutil
import sys
from typing import Tuple, List

from arcgis.features import GeoAccessor, GeoSeriesAccessor

import boto3
from dotenv import load_dotenv, find_dotenv
import pandas as pd

# %%
# paths to common data locations - NOTE: to convert any path to a raw string, simply use str(path_instance)
dir_prj = Path('./').absolute().parent

dir_data = dir_prj/'data'

dir_raw = dir_data/'raw'
dir_ext = dir_data/'external'
dir_int = dir_data/'interim'
dir_out = dir_data/'processed'

gdb_raw = dir_raw/'raw.gdb'
gdb_int = dir_int/'interim.gdb'
gdb_out = dir_out/'processed.gdb'

# import the project package from the project package path
sys.path.append(str(dir_prj/'src'))
import uw_parks

# load the "autoreload" extension so that code can change, & always reload modules so that as you change code in src, it gets loaded
# %load_ext autoreload
# %autoreload 2

# load environment variables from .env
load_dotenv(find_dotenv())
# Out:
# True

# %% [markdown]
# # Get Patterns from Safegraph
#
# Safegraph Patterns datasets are all available for download by month as complete datasets split into sequential files based on size. Yes, this sounds a little confusing at first, but it is a pretty common practice for big data. The data is organized into directories by year, then by month, and

# %%
def get_year_month(pth: Path) -> Tuple[int, int]:
    """Get the year and month from the file path convention- useful for filtering."""
    
    pth = Path(pth) if isinstance(pth, str) else pth
    
    # get the year and month from the path depending on whether or not it is from the backports
    if 'backfill' in str(pth):
        yr_mth = pth.parts[6:8]
    else:
        yr_mth = pth.parts[2:4]
        
    # convert the year and month to integers for sorting
    yr_mth = tuple(int(val) for val in yr_mth)
    
    return yr_mth


def get_standardized_path(pth: Path) -> Path:
    """Get a standardized path for saving."""
    
    # get the year and the month from the file path
    year, month = get_year_month(pth)
    
    # get all the path parts
    pth_prts = Path(pth).parts
    
    # now, standardize the path
    pth_root = Path(pth_prts[0])
    typ = pth_prts[1].replace('_backfill', '')
    fl_nm = pth_prts[-1]
    
    # put everything back together in a standard schema
    out_pth = pth_root/typ/f'{year:04d}'/f'{month:02d}'/fl_nm
    
    return out_pth

def get_resource_type(pth: Path) -> str:
    """Get the resource type from the path - useful for finding the right resources."""
    typ = Path(pth).parts[1].replace('_backfill', '')
    return typ

def get_content_dataframe(s3, bucket='sg-c19-response', prefix='monthly-patterns'):
    """Provide ability to introspectively retrieve a dataframe of monthly patterns data."""

    # get the contents of the bucket with the specified prefix
    bkt_ls = s3.list_objects(Bucket=bucket, Prefix=prefix)
    cntnts = bkt_ls['Contents']

    # get a dataframe of all the available resources, starting with the S3 bucket path
    cntnt_df = pd.Series([itm['Key'] for itm in cntnts if not itm['Key'].endswith('_SUCCESS')], name='source_path').to_frame()

    # calculate the year and month for the resource
    cntnt_df[['year', 'month']] = cntnt_df.source_path.apply(lambda pth: pd.Series(get_year_month(pth)))

    # get the resource category
    cntnt_df['resource_type'] = cntnt_df.source_path.apply(lambda pth: get_resource_type(pth))

    # get a standardized path - useful for saving outputs
    cntnt_df['standardized_path'] = cntnt_df.source_path.apply(lambda pth: get_standardized_path(pth))

    return cntnt_df

def check_list(in_lst, dtype=str):
    """Helper function to ensure input is a list of correct data type."""
    
    assert isinstance(in_lst, (list, dtype))
            
    if isinstance(in_lst, list):
        for itm in in_lst: 
            assert isinstance(itm, dtype)
    else:
        in_lst = [in_lst]
            
    return in_lst


class SafegraphClient:
    """Client streamlining process of retrieving data from AWS S3 and preparing a proejct for analysis."""
    
    def __init__(self, bucket='sg-c19-response', prefix='monthly-patterns', access_key=None, secret_key=None):
        
        self.bucket = bucket
        self.prefix = prefix
        
        if access_key or secret_key:
            assert (access_key and secret_key), 'If explicitly providing an access_key and secret_key for accessing AWS S3, you must provide both.'

        # retrieve credentials from environment variables if not explicitly provided
        access_key = os.getenv('AWS_KEY') if not access_key else access_key
        secret_key = os.getenv('AWS_SECRET') if not secret_key else secret_key

        assert access_key, 'If "AWS_KEY" is not set in the environment variables, it must be explicitly provided in the "access_key" parameter.'
        assert secret_key, 'If "AWS_SECRET" is not set in the environment variables, it must be explicitly provided in the "secret_key" parameter.'

        # start a session connecting to AWS with credentials
        aws_session = boto3.Session(aws_access_key_id=access_key, aws_secret_access_key=secret_key, region_name='us-east-1')

        # using the authenticated session, create an S3 client accessing the safegraph data
        self.s3 = aws_session.client('s3', endpoint_url='https://s3.wasabisys.com')
        
        self._content_dataframe = None
        
    @property
    def content_dataframe(self):
        
        if self._content_dataframe is None:
            self._content_dataframe = get_content_dataframe(self.s3, self.bucket, self.prefix)
            
        return self._content_dataframe

    def get_dataframe_from_remote_path(self, source_s3_path:str):
        """Get a dataframe for a resource using the remove path, the, "Key," referncing the path within the bucket in AWS S3."""
        
        src_pth = str(source_s3_path) if isinstance(source_s3_path, Path) else source_s3_path
        
        assert self.content_dataframe.source_path.str.contains(src_pth).any()
        
        # get the headers describing the file
        resp = self.s3.get_object(Bucket=self.bucket, Key=src_pth)
        
        # handle compressed data differently - only applies to patterns data
        if resp['ContentType'] == 'application/gzip':
            
            # create a gzip object mapped to the stream
            gz = GzipFile(fileobj=resp.get('Body'))
            
            # stream into a pandas dataframe
            df = pd.read_csv(gz, dtype=str)
            
        # the rest are just in flat csv's, so use BytesIO for them
        else:
            byt = BytesIO(resp.get('Body').read())    
            df = pd.read_csv(byt)
            
        return df

    
    def get_patterns_dataframe(self, year:[int, List[int]], month:[int, List[int]]=None, safegraph_pois:[str, List[str]]=None, 
                               placekeys:[str, List[str]]=None) -> pd.DataFrame:
        """Get a patterns dataframe for a specific month and year with the option (recommended) to filter to a specific point of interest using the Safegraph POI ID."""
        
        year = check_list(year, int)
        
        if month is not None:
            month = check_list(month, int)
            
            # filter the content for just this month's patterns data
            ym_cntnt_df = self.content_dataframe[(self.content_dataframe.year.isin(year)) & 
                                                 (self.content_dataframe.month.isin(month)) & 
                                                 (self.content_dataframe.resource_type == 'patterns')]
            
        else:
            # filter the content for just this month's patterns data
            ym_cntnt_df = self.content_dataframe[(self.content_dataframe.year.isin(year)) &
                                                 (self.content_dataframe.resource_type == 'patterns')]

        # empty list to populate
        ym_df_lst = []

        # for every one of the remote files
        for pth in ym_cntnt_df.source_path:
            
            # get a dataframe for the remote file
            tmp_df = self.get_dataframe_from_remote_path(pth)
            
            # filter the dataframe based on Safegraph POI ID's
            if safegraph_pois is not None:
                safegraph_pois = check_list(safegraph_pois, str)
                tmp_df = tmp_df[(tmp_df.safegraph_place_id.isin(safegraph_pois))]
                
            # filter the dataframe based on Placekeys
            if placekeys is not None:
                placekeys = check_list(placekeys, str)
                tmp_df = tmp_df[(tmp_df.placekey.isin(placekeys))]
            
            # add the dataframe to the list
            ym_df_lst.append(tmp_df)

        # combine all the output dataframes
        ym_df = pd.concat(ym_df_lst)
        
        return ym_df

# %%
sg = SafegraphClient()

sg

# %%
sg_poi = 'sg:af471021a929414cbf69854e6f8f1b0c'  # white pass

# %%
wp_y2019_y2020_df = sg.get_patterns_dataframe([2018, 2019, 2020], safegraph_pois=sg_poi)

wp_y2019_y2020_df
# Out:
#                          safegraph_place_id        location_name  \
# 137646  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 199898  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 198080  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 137469  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 86499   sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 169339  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 233622  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 94681   sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 128545  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 119562  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 143458  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 184700  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 191186  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 226235  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 31424   sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 189140  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 197813  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 168211  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 228611  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 178995  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 158825  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 137495  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 187308  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 157857  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 224525  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 234334  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 228994  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 165000  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 162027  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 129252  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 167450  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 140580  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 159573  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 110570  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
# 111127  sg:af471021a929414cbf69854e6f8f1b0c  White Pass Ski Area
#
#        street_address    city region postal_code safegraph_brand_ids brands  \
# 137646  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 199898  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 198080  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 137469  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 86499   48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 169339  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 233622  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 94681   48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 128545  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 119562  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 143458  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 184700  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 191186  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 226235  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 31424   48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 189140  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 197813  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 168211  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 228611  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 178995  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 158825  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 137495  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 187308  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 157857  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 224525  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 234334  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 228994  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 165000  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 162027  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 129252  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 167450  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 140580  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 159573  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 110570  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
# 111127  48935 U.s. 12  Naches     WA       98937                 NaN    NaN
#
#                  date_range_start             date_range_end  ...  \
# 137646  2020-05-01T00:00:00-07:00  2020-06-01T00:00:00-07:00  ...
# 199898  2020-06-01T00:00:00-07:00  2020-07-01T00:00:00-07:00  ...
# 198080  2020-07-01T00:00:00-07:00  2020-08-01T00:00:00-07:00  ...
# 137469  2020-08-01T00:00:00-07:00  2020-09-01T00:00:00-07:00  ...
# 86499   2020-09-01T00:00:00-07:00  2020-10-01T00:00:00-07:00  ...
# 169339  2020-10-01T00:00:00-07:00  2020-11-01T00:00:00-07:00  ...
# 233622  2020-11-01T00:00:00-07:00  2020-12-01T00:00:00-08:00  ...
# 94681   2018-01-01T00:00:00-08:00  2018-02-01T00:00:00-08:00  ...
# 128545  2018-02-01T00:00:00-08:00  2018-03-01T00:00:00-08:00  ...
# 119562  2018-03-01T00:00:00-08:00  2018-04-01T00:00:00-07:00  ...
# 143458  2018-04-01T00:00:00-07:00  2018-05-01T00:00:00-07:00  ...
# 184700  2018-05-01T00:00:00-07:00  2018-06-01T00:00:00-07:00  ...
# 191186  2018-06-01T00:00:00-07:00  2018-07-01T00:00:00-07:00  ...
# 226235  2018-07-01T00:00:00-07:00  2018-08-01T00:00:00-07:00  ...
# 31424   2018-08-01T00:00:00-07:00  2018-09-01T00:00:00-07:00  ...
# 189140  2018-09-01T00:00:00-07:00  2018-10-01T00:00:00-07:00  ...
# 197813  2018-10-01T00:00:00-07:00  2018-11-01T00:00:00-07:00  ...
# 168211  2018-11-01T00:00:00-07:00  2018-12-01T00:00:00-08:00  ...
# 228611  2018-12-01T00:00:00-08:00  2019-01-01T00:00:00-08:00  ...
# 178995  2019-01-01T00:00:00-08:00  2019-02-01T00:00:00-08:00  ...
# 158825  2019-02-01T00:00:00-08:00  2019-03-01T00:00:00-08:00  ...
# 137495  2019-03-01T00:00:00-08:00  2019-04-01T00:00:00-07:00  ...
# 187308  2019-04-01T00:00:00-07:00  2019-05-01T00:00:00-07:00  ...
# 157857  2019-05-01T00:00:00-07:00  2019-06-01T00:00:00-07:00  ...
# 224525  2019-06-01T00:00:00-07:00  2019-07-01T00:00:00-07:00  ...
# 234334  2019-07-01T00:00:00-07:00  2019-08-01T00:00:00-07:00  ...
# 228994  2019-08-01T00:00:00-07:00  2019-09-01T00:00:00-07:00  ...
# 165000  2019-09-01T00:00:00-07:00  2019-10-01T00:00:00-07:00  ...
# 162027  2019-10-01T00:00:00-07:00  2019-11-01T00:00:00-07:00  ...
# 129252  2019-11-01T00:00:00-07:00  2019-12-01T00:00:00-08:00  ...
# 167450  2019-12-01T00:00:00-08:00  2020-01-01T00:00:00-08:00  ...
# 140580  2020-01-01T00:00:00-08:00  2020-02-01T00:00:00-08:00  ...
# 159573  2020-02-01T00:00:00-08:00  2020-03-01T00:00:00-08:00  ...
# 110570  2020-03-01T00:00:00-08:00  2020-04-01T00:00:00-07:00  ...
# 111127  2020-04-01T00:00:00-07:00  2020-05-01T00:00:00-07:00  ...
#
#        median_dwell                               bucketed_dwell_times  \
# 137646         21.0  {"<5":3,"5-20":56,"21-60":26,"61-240":27,">240...
# 199898         35.0  {"<5":1,"5-20":17,"21-60":7,"61-240":18,">240":2}
# 198080         24.0  {"<5":3,"5-20":33,"21-60":22,"61-240":12,">240...
# 137469         22.0  {"<5":3,"5-20":37,"21-60":24,"61-240":13,">240...
# 86499          52.5  {"<5":1,"5-20":34,"21-60":32,"61-240":23,">240...
# 169339         72.0  {"<5":1,"5-20":30,"21-60":12,"61-240":25,">240...
# 233622         35.0  {"<5":23,"5-10":111,"11-20":73,"21-60":166,"61...
# 94681          51.0  {"<5":26,"5-20":218,"21-60":284,"61-240":286,"...
# 128545         63.0  {"<5":11,"5-20":213,"21-60":217,"61-240":277,"...
# 119562         55.0  {"<5":5,"5-20":200,"21-60":243,"61-240":251,">...
# 143458         59.0  {"<5":1,"5-20":112,"21-60":130,"61-240":144,">...
# 184700         60.0  {"<5":1,"5-20":33,"21-60":45,"61-240":36,">240...
# 191186         56.0  {"<5":1,"5-20":41,"21-60":13,"61-240":26,">240...
# 226235         69.5  {"<5":6,"5-20":49,"21-60":34,"61-240":61,">240...
# 31424         163.5  {"<5":4,"5-20":161,"21-60":113,"61-240":162,">...
# 189140         34.0  {"<5":1,"5-20":24,"21-60":11,"61-240":12,">240...
# 197813         68.0  {"<5":0,"5-20":16,"21-60":9,"61-240":15,">240"...
# 168211         56.0  {"<5":1,"5-20":20,"21-60":19,"61-240":21,">240...
# 228611         45.0  {"<5":19,"5-20":429,"21-60":500,"61-240":529,"...
# 178995         44.0  {"<5":34,"5-20":555,"21-60":588,"61-240":595,"...
# 158825         42.0  {"<5":25,"5-20":518,"21-60":556,"61-240":550,"...
# 137495         44.0  {"<5":30,"5-20":439,"21-60":476,"61-240":477,"...
# 187308         48.5  {"<5":6,"5-20":188,"21-60":185,"61-240":185,">...
# 157857         31.0  {"<5":0,"5-20":28,"21-60":17,"61-240":16,">240...
# 224525         16.0  {"<5":3,"5-20":38,"21-60":14,"61-240":10,">240...
# 234334         60.5  {"<5":1,"5-20":84,"21-60":60,"61-240":96,">240...
# 228994         23.0  {"<5":3,"5-20":28,"21-60":19,"61-240":10,">240...
# 165000         25.0  {"<5":1,"5-20":22,"21-60":9,"61-240":8,">240":10}
# 162027         60.5  {"<5":1,"5-20":35,"21-60":33,"61-240":46,">240...
# 129252         96.0  {"<5":1,"5-20":22,"21-60":21,"61-240":38,">240...
# 167450         45.0  {"<5":29,"5-20":599,"21-60":736,"61-240":741,"...
# 140580         42.0  {"<5":71,"5-20":995,"21-60":1178,"61-240":1109...
# 159573         46.0  {"<5":44,"5-20":743,"21-60":897,"61-240":891,"...
# 110570         48.0  {"<5":17,"5-20":288,"21-60":318,"61-240":358,"...
# 111127         30.5  {"<5":3,"5-20":38,"21-60":22,"61-240":29,">240...
#
#                                    related_same_day_brand  \
# 137646            {"Fred Meyer Jewelers":33,"Chevron":32}
# 199898                                                 {}
# 198080                                                 {}
# 137469                                                 {}
# 86499                                                  {}
# 169339                                                 {}
# 233622                                                 {}
# 94681   {"McDonald's":14,"Fred Meyer":8,"Fitness 19":7...
# 128545  {"Comfort Inn":17,"KeyBank":11,"Volkswagen":8,...
# 119562                                                 {}
# 143458                                                 {}
# 184700                                                 {}
# 191186               {"Applebee's":50,"ConocoPhillips":9}
# 226235                                                 {}
# 31424     {"Best Buy":17,"Marriott Hotels":6,"Safeway":6}
# 189140                                    {"Marathon":25}
# 197813                                                 {}
# 168211                                {"Ace Hardware":25}
# 228611       {"Boys & Girls Clubs of America":50,"IGA":5}
# 178995  {"Jo-Ann Fabric and Craft Stores":11,"Chevron":9}
# 158825           {"Chevron":10,"Dick's Sporting Goods":7}
# 137495  {"Best Western":10,"Burger King":9,"Shell Oil"...
# 187308  {"Target":32,"Chevron":13,"Simon mall":12,"Sta...
# 157857  {"Safeway Pharmacy":50,"Safeway Fuel Station":25}
# 224525                                    {"Cinnabon":50}
# 234334            {"Safeway":20,"Starbucks":6,"Lowe's":6}
# 228994  {"ARCO":66,"Love's Travel Stops and Country St...
# 165000   {"Fred Meyer":100,"Dairy Queen":50,"Chevron":19}
# 162027                                                 {}
# 129252           {"Ford Motor Company":50,"Shell Oil":15}
# 167450                                                 {}
# 140580                                   {"McDonald's":6}
# 159573  {"Walmart":9,"Red Lobster":7,"Skippers":6,"Lov...
# 110570                 {"Starbucks":18,"IGA":12,"ARCO":9}
# 111127                                                 {}
#
#                                  related_same_month_brand  \
# 137646  {"Chevron":37,"Walmart":24,"76":23,"Safeway":2...
# 199898  {"Chevron":34,"Shell Oil":34,"Safeway Fuel Sta...
# 198080  {"Chevron":43,"Walmart":29,"76":26,"Shell Oil"...
# 137469  {"Chevron":42,"Shell Oil":32,"Safeway":28,"76"...
# 86499   {"Costco Wholesale Corp.":31,"76":29,"Shell Oi...
# 169339  {"Chevron":27,"76":24,"Shell Oil":20,"Starbuck...
# 233622  {"Starbucks":29,"Safeway":26,"Chevron":25,"Cos...
# 94681   {"Starbucks":31,"Chevron":28,"Costco Wholesale...
# 128545  {"Chevron":28,"Safeway":27,"Starbucks":26,"Cos...
# 119562  {"Starbucks":29,"Costco Wholesale Corp.":29,"C...
# 143458  {"Costco Wholesale Corp.":33,"Safeway":27,"Che...
# 184700  {"Chevron":36,"McDonald's":33,"Shell Oil":32,"...
# 191186  {"Chevron":37,"Walmart":32,"Shell Oil":31,"Saf...
# 226235  {"Safeway":32,"Chevron":30,"Costco Wholesale C...
# 31424   {"Chevron":25,"Safeway":15,"Shell Oil":14,"76"...
# 189140  {"Chevron":29,"Safeway":24,"Walmart":24,"McDon...
# 197813  {"Chevron":31,"McDonald's":26,"Shell Oil":23,"...
# 168211  {"Chevron":41,"Safeway":31,"Walmart":28,"Shell...
# 228611  {"Costco Wholesale Corp.":38,"Starbucks":36,"C...
# 178995  {"Starbucks":30,"Costco Wholesale Corp.":30,"S...
# 158825  {"Costco Wholesale Corp.":29,"Starbucks":28,"S...
# 137495  {"Starbucks":32,"Chevron":32,"Costco Wholesale...
# 187308  {"Starbucks":32,"Chevron":30,"Costco Wholesale...
# 157857  {"Shell Oil":42,"Walmart":41,"Chevron":39,"Saf...
# 224525  {"Chevron":45,"Walmart":37,"Shell Oil":34,"Saf...
# 234334  {"Shell Oil":35,"Safeway":32,"Chevron":32,"Sta...
# 228994  {"Walmart":53,"Chevron":49,"Shell Oil":35,"McD...
# 165000  {"Chevron":44,"Safeway":40,"Walmart":33,"Subwa...
# 162027  {"McDonald's":33,"Walmart":33,"Chevron":29,"Sh...
# 129252  {"Chevron":34,"Walmart":31,"ARCO":31,"Safeway"...
# 167450  {"Starbucks":33,"Costco Wholesale Corp.":32,"S...
# 140580  {"Starbucks":29,"Safeway":29,"Costco Wholesale...
# 159573  {"Starbucks":31,"Costco Wholesale Corp.":30,"S...
# 110570  {"Costco Wholesale Corp.":29,"Safeway":29,"Che...
# 111127  {"Chevron":31,"Safeway":27,"Safeway Pharmacy":...
#
#                                        popularity_by_hour  \
# 137646  [5,4,3,2,4,4,4,12,21,28,27,26,23,22,26,22,9,11...
# 199898  [0,1,2,2,2,1,1,10,10,11,11,11,5,12,12,10,2,1,0...
# 198080  [2,2,2,2,4,3,1,6,9,8,13,15,25,23,22,15,9,3,3,6...
# 137469  [2,2,2,2,3,2,4,20,17,20,16,21,22,21,17,16,9,4,...
# 86499   [13,14,11,12,12,13,21,31,28,28,31,27,28,32,29,...
# 169339  [10,9,10,9,8,9,8,22,24,25,26,27,30,28,23,21,15...
# 233622  [11,11,10,11,7,7,15,50,114,145,154,174,165,143...
# 94681   [80,79,77,76,73,72,82,133,246,264,238,278,297,...
# 128545  [115,117,118,116,117,117,115,147,236,278,289,2...
# 119562  [66,65,62,62,61,57,61,102,213,232,240,251,269,...
# 143458  [30,29,28,28,26,25,29,50,123,143,160,163,165,1...
# 184700  [5,4,4,4,3,3,14,36,38,40,45,49,52,60,46,40,36,...
# 191186  [3,4,4,3,3,3,10,19,26,29,27,25,33,36,35,29,24,...
# 226235  [18,18,16,17,18,14,31,35,45,48,46,70,71,57,45,...
# 31424   [262,261,263,259,259,296,278,267,218,199,199,1...
# 189140  [5,6,6,5,5,5,7,11,18,19,12,13,10,11,10,14,8,5,...
# 197813  [2,2,2,4,4,4,4,15,15,18,19,14,14,13,12,8,5,3,2...
# 168211  [10,10,9,8,9,11,11,16,17,18,17,14,14,12,15,13,...
# 228611  [66,65,67,65,66,71,73,115,296,398,399,432,476,...
# 178995  [107,108,109,113,106,107,112,176,383,469,480,5...
# 158825  [82,88,92,95,93,96,99,177,418,467,442,472,511,...
# 137495  [92,95,92,93,89,93,101,191,364,380,389,413,444...
# 187308  [36,38,41,42,45,46,54,83,141,157,153,183,213,1...
# 157857  [6,8,9,9,11,9,7,6,5,6,6,11,12,18,12,9,4,6,4,4,...
# 224525  [4,4,4,4,5,7,11,9,9,5,13,11,9,9,6,7,7,4,5,2,3,...
# 234334  [36,34,34,39,36,37,37,38,40,37,53,77,88,47,43,...
# 228994  [8,8,8,8,8,10,10,8,8,10,12,15,9,9,12,8,3,6,9,9...
# 165000  [1,1,1,1,3,3,0,9,11,11,14,16,18,16,10,10,7,3,3...
# 162027  [6,6,9,7,7,8,12,34,37,34,34,35,34,33,34,30,22,...
# 129252  [5,6,8,6,6,5,9,20,37,45,44,40,40,40,27,21,7,7,...
# 167450  [77,70,67,65,66,68,78,195,444,581,583,665,752,...
# 140580  [139,131,124,124,127,128,134,351,753,905,852,9...
# 159573  [108,113,111,105,106,111,135,328,622,744,675,7...
# 110570  [38,41,38,38,37,38,38,124,258,280,277,313,347,...
# 111127  [1,1,1,1,1,1,1,3,6,15,23,35,27,21,20,12,17,3,2...
#
#                                         popularity_by_day  \
# 137646  {"Monday":11,"Tuesday":20,"Wednesday":15,"Thur...
# 199898  {"Monday":11,"Tuesday":7,"Wednesday":5,"Thursd...
# 198080  {"Monday":10,"Tuesday":10,"Wednesday":11,"Thur...
# 137469  {"Monday":19,"Tuesday":15,"Wednesday":10,"Thur...
# 86499   {"Monday":21,"Tuesday":10,"Wednesday":31,"Thur...
# 169339  {"Monday":13,"Tuesday":18,"Wednesday":19,"Thur...
# 233622  {"Monday":46,"Tuesday":9,"Wednesday":18,"Thurs...
# 94681   {"Monday":136,"Tuesday":52,"Wednesday":71,"Thu...
# 128545  {"Monday":116,"Tuesday":75,"Wednesday":62,"Thu...
# 119562  {"Monday":28,"Tuesday":48,"Wednesday":68,"Thur...
# 143458  {"Monday":33,"Tuesday":40,"Wednesday":47,"Thur...
# 184700  {"Monday":21,"Tuesday":24,"Wednesday":28,"Thur...
# 191186  {"Monday":20,"Tuesday":21,"Wednesday":17,"Thur...
# 226235  {"Monday":35,"Tuesday":32,"Wednesday":41,"Thur...
# 31424   {"Monday":102,"Tuesday":93,"Wednesday":120,"Th...
# 189140  {"Monday":9,"Tuesday":10,"Wednesday":7,"Thursd...
# 197813  {"Monday":1,"Tuesday":7,"Wednesday":11,"Thursd...
# 168211  {"Monday":5,"Tuesday":0,"Wednesday":4,"Thursda...
# 228611  {"Monday":273,"Tuesday":76,"Wednesday":165,"Th...
# 178995  {"Monday":208,"Tuesday":261,"Wednesday":94,"Th...
# 158825  {"Monday":229,"Tuesday":177,"Wednesday":131,"T...
# 137495  {"Monday":105,"Tuesday":74,"Wednesday":74,"Thu...
# 187308  {"Monday":34,"Tuesday":33,"Wednesday":38,"Thur...
# 157857  {"Monday":8,"Tuesday":9,"Wednesday":12,"Thursd...
# 224525  {"Monday":10,"Tuesday":6,"Wednesday":6,"Thursd...
# 234334  {"Monday":35,"Tuesday":41,"Wednesday":67,"Thur...
# 228994  {"Monday":6,"Tuesday":9,"Wednesday":5,"Thursda...
# 165000  {"Monday":8,"Tuesday":5,"Wednesday":7,"Thursda...
# 162027  {"Monday":6,"Tuesday":18,"Wednesday":13,"Thurs...
# 129252  {"Monday":15,"Tuesday":9,"Wednesday":13,"Thurs...
# 167450  {"Monday":380,"Tuesday":258,"Wednesday":132,"T...
# 140580  {"Monday":307,"Tuesday":143,"Wednesday":322,"T...
# 159573  {"Monday":254,"Tuesday":121,"Wednesday":161,"T...
# 110570  {"Monday":43,"Tuesday":40,"Wednesday":24,"Thur...
# 111127  {"Monday":8,"Tuesday":12,"Wednesday":14,"Thurs...
#
#                       device_type             placekey parent_placekey  \
# 137646    {"android":44,"ios":32}                  NaN             NaN
# 199898     {"android":13,"ios":7}                  NaN             NaN
# 198080    {"android":38,"ios":21}                  NaN             NaN
# 137469    {"android":39,"ios":17}                  NaN             NaN
# 86499     {"android":31,"ios":14}  zzy-222@5xd-7jh-f75             NaN
# 169339    {"android":17,"ios":19}  zzy-222@5xd-7jh-f75             NaN
# 233622  {"android":107,"ios":176}  zzw-222@5xd-7jh-ffz             NaN
# 94681   {"android":120,"ios":248}                  NaN             NaN
# 128545  {"android":108,"ios":261}                  NaN             NaN
# 119562  {"android":118,"ios":207}                  NaN             NaN
# 143458    {"android":88,"ios":93}                  NaN             NaN
# 184700    {"android":28,"ios":21}                  NaN             NaN
# 191186    {"android":24,"ios":26}                  NaN             NaN
# 226235    {"android":42,"ios":44}                  NaN             NaN
# 31424     {"android":83,"ios":62}                  NaN             NaN
# 189140    {"android":17,"ios":22}                  NaN             NaN
# 197813     {"android":26,"ios":7}                  NaN             NaN
# 168211    {"android":19,"ios":19}                  NaN             NaN
# 228611  {"android":246,"ios":420}                  NaN             NaN
# 178995  {"android":320,"ios":454}                  NaN             NaN
# 158825  {"android":260,"ios":372}                  NaN             NaN
# 137495  {"android":270,"ios":324}                  NaN             NaN
# 187308  {"android":112,"ios":130}                  NaN             NaN
# 157857     {"android":33,"ios":9}                  NaN             NaN
# 224525    {"android":31,"ios":18}                  NaN             NaN
# 234334    {"android":69,"ios":57}                  NaN             NaN
# 228994    {"android":43,"ios":17}                  NaN             NaN
# 165000    {"android":22,"ios":15}                  NaN             NaN
# 162027    {"android":33,"ios":21}                  NaN             NaN
# 129252    {"android":24,"ios":21}                  NaN             NaN
# 167450  {"android":399,"ios":473}                  NaN             NaN
# 140580  {"android":617,"ios":650}                  NaN             NaN
# 159573  {"android":493,"ios":516}                  NaN             NaN
# 110570  {"android":234,"ios":195}                  NaN             NaN
# 111127    {"android":44,"ios":20}                  NaN             NaN
#
#        parent_safegraph_place_id
# 137646                       NaN
# 199898                       NaN
# 198080                       NaN
# 137469                       NaN
# 86499                        NaN
# 169339                       NaN
# 233622                       NaN
# 94681                        NaN
# 128545                       NaN
# 119562                       NaN
# 143458                       NaN
# 184700                       NaN
# 191186                       NaN
# 226235                       NaN
# 31424                        NaN
# 189140                       NaN
# 197813                       NaN
# 168211                       NaN
# 228611                       NaN
# 178995                       NaN
# 158825                       NaN
# 137495                       NaN
# 187308                       NaN
# 157857                       NaN
# 224525                       NaN
# 234334                       NaN
# 228994                       NaN
# 165000                       NaN
# 162027                       NaN
# 129252                       NaN
# 167450                       NaN
# 140580                       NaN
# 159573                       NaN
# 110570                       NaN
# 111127                       NaN
#
# [35 rows x 29 columns]

# %%
wp_y2019_y2020_df.to_csv(dir_raw/'patterns_wp.csv')

# %% [markdown]
# # SG BG JSON

# %%
geojson_pth = dir_raw/'safegraph_open_census_data'/'geometry'/'cbg.geojson'

geojson_pth
# Out:
# WindowsPath('D:/projects/pdx-parks/data/raw/safegraph_open_census_data/geometry/cbg.geojson')

# %%
with open(geojson_pth, 'rb') as geojson_file:
    geojson = json.load(geojson_file)

# %%
bg_df = pd.DataFrame([f['properties'] for f in geojson['features']])

# %%
from arcgis.geometry import Geometry, SpatialReference
sr = SpatialReference(4326)
sr
# Out:
# {'wkid': 4326}

# %%
bg_df['SHAPE'] = [Geometry({"rings" : g['geometry']['coordinates'][0], "spatialReference": sr}) for g in geojson['features']]

# %%
bg_df.spatial.set_geometry('SHAPE')

# %%
bg_df.spatial.validate()
# Out:
# True

# %%
bg_df.head()
# Out:
#   StateFIPS CountyFIPS TractCode BlockGroup CensusBlockGroup State  \
# 0        01        081    041600          1     010810416001    AL
# 1        01        081    041600          2     010810416002    AL
# 2        01        081    041700          4     010810417004    AL
# 3        01        073    011107          4     010730111074    AL
# 4        01        073    011108          4     010730111084    AL
#
#              County ClassCode  \
# 0        Lee County        H1
# 1        Lee County        H1
# 2        Lee County        H1
# 3  Jefferson County        H1
# 4  Jefferson County        H1
#
#                                                SHAPE
# 0  {"rings": [[[-85.37281500011215, 32.6342380002...
# 1  {"rings": [[[-85.38346400016343, 32.6483780003...
# 2  {"rings": [[[-85.37139200014064, 32.6013869998...
# 3  {"rings": [[[-86.64796800012306, 33.5920459996...
# 4  {"rings": [[[-86.65205899992287, 33.5986850000...

# %%
bg_df.spatial.to_featureclass(gdb_raw/'sg_cbg')
# Out:
# 'D:\\projects\\pdx-parks\\data\\raw\\raw.gdb\\sg_cbg'

# %%
out_df = home_cbgs_df.join(bg_df.set_index('CensusBlockGroup')['SHAPE'])
out_df
# Out:
#               visitor_home_count  \
# 410510007022                  22
# 410510007021                  12
# 410510006024                  10
# 410510090001                   9
# 410510016022                   7
# ...                          ...
# 410510091022                   4
# 410050222071                   4
# 410510005024                   4
# 410510072021                   4
# 120090647005                   4
#
#                                                           SHAPE
# 410510007022  {'rings': [[[-122.59121099978778, 45.490623000...
# 410510007021  {'rings': [[[-122.58482500027351, 45.497428000...
# 410510006024  {'rings': [[[-122.57903200022663, 45.478235999...
# 410510090001  {'rings': [[[-122.53769799976283, 45.490802000...
# 410510016022  {'rings': [[[-122.57310700038772, 45.512254000...
# ...                                                         ...
# 410510091022  {'rings': [[[-122.52356500002469, 45.490155000...
# 410050222071  {'rings': [[[-122.53383599973161, 45.427781999...
# 410510005024  {'rings': [[[-122.58930099984121, 45.478932999...
# 410510072021  {'rings': [[[-122.79113000014934, 45.625901999...
# 120090647005  {'rings': [[[-80.65456599982099, 28.0855010001...
#
# [78 rows x 2 columns]

# %%
out_df.spatial.to_featureclass(gdb_int/'test05')
# Out:
# 'D:\\projects\\pdx-parks\\data\\interim\\interim.gdb\\test05'
