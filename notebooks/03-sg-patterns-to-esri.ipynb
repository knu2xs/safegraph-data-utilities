# %%
    import importlib
import json
import os
from pathlib import Path
import shutil
import sys

from arcgis.features import GeoAccessor, GeoSeriesAccessor
from arcgis.gis import GIS
import boto3
from dotenv import load_dotenv, find_dotenv
import pandas as pd
from tqdm import tqdm
import zipfile

# %%
# paths to common data locations - NOTE: to convert any path to a raw string, simply use str(path_instance)
dir_prj = Path('./').absolute().parent

dir_data = dir_prj/'data'

dir_raw = dir_data/'raw'
dir_ext = dir_data/'external'
dir_int = dir_data/'interim'
dir_out = dir_data/'processed'

gdb_raw = dir_raw/'raw.gdb'
gdb_int = dir_int/'interim.gdb'
gdb_out = dir_out/'processed.gdb'

# import the project package from the project package path
sys.path.append(str(dir_prj/'src'))
import pdx_parks

# load the "autoreload" extension so that code can change, & always reload modules so that as you change code in src, it gets loaded
# %load_ext autoreload
# %autoreload 2

# load environment variables from .env
load_dotenv(find_dotenv())
# Out:
# True

# %%
ptrns_df = pd.read_parquet(dir_int/'sg'/'patterns.parquet')

ptrns_df[['safegraph_place_id', 'raw_visit_counts', 'distance_from_home', 'year', 'month']].head()
# Out:
#                     safegraph_place_id  raw_visit_counts  distance_from_home  \
# 0  sg:465da3a640834193b3167cb8214a7325               204           1198783.0
# 1  sg:c3ab3119ff924f5f8438f8075d61a1dd               418             10173.0
# 2  sg:a2b62948ca5f4395b86678a216a51190                33             10871.0
# 3  sg:06a21e9e0fc144a988d669990c3f01f5               344             16883.0
# 4  sg:f160ad07acb54f7db8e052b025a4a241                 3                 NaN
#
#    year  month
# 0  2019      6
# 1  2019      6
# 2  2019      6
# 3  2019      6
# 4  2019      6

# %%
import itertools

ptrns_jul_df = ptrns_df[ptrns_df.month == 7][['safegraph_place_id', 'raw_visit_counts', 'distance_from_home', 'year', 'month']]

comp_df = pd.Series(ptrns_jul_df.safegraph_place_id.unique()).to_frame('safegraph_place_id')

for mtrc_yr in itertools.product(['raw_visit_counts', 'distance_from_home'], ptrns_jul_df.year.unique()):
    metric = mtrc_yr[0]
    year = mtrc_yr[1]
    col = f'{metric}_{year}'
    comp_tmp = ptrns_jul_df[ptrns_jul_df.year == year][['safegraph_place_id', metric]].set_index('safegraph_place_id')
    comp_tmp.columns = [col]
    comp_df = comp_df.join(comp_tmp, on='safegraph_place_id')
    
comp_df
# Out:
#                       safegraph_place_id  raw_visit_counts_2019  \
# 0    sg:465da3a640834193b3167cb8214a7325                  253.0
# 1    sg:c3ab3119ff924f5f8438f8075d61a1dd                  419.0
# 2    sg:a2b62948ca5f4395b86678a216a51190                   52.0
# 3    sg:06a21e9e0fc144a988d669990c3f01f5                  420.0
# 4    sg:170d6d8a39d44f22874af1f35799b89a                 2168.0
# ..                                   ...                    ...
# 357  sg:077d2286767c473fa7c1d8574556a575                    NaN
# 358  sg:3e6650089ebb4c50abe2c49d43b1f976                    NaN
# 359  sg:5899cdce314f4355ba4cf32ac5ae746e                    NaN
# 360  sg:f9fab565f35946cb972dcad4f2c4f15f                    NaN
# 361  sg:185eefa304cb48ceb639f3464bfaf26d                    NaN
#
#      raw_visit_counts_2020  distance_from_home_2019  distance_from_home_2020
# 0                    130.0                1370819.0                1125234.0
# 1                    274.0                   7399.0                   8234.0
# 2                     16.0                  12051.0                   6742.0
# 3                    542.0                  18807.0                  18996.0
# 4                    737.0                  10088.0                   5540.0
# ..                     ...                      ...                      ...
# 357                   39.0                      NaN                   7720.0
# 358                   28.0                      NaN                   5246.0
# 359                   67.0                      NaN                  10495.0
# 360                 1330.0                      NaN                  15177.0
# 361                  702.0                      NaN                  11547.0
#
# [362 rows x 5 columns]

# %%
comp_df['raw_visit_counts_delta'] = comp_df['raw_visit_counts_2020'] - comp_df['raw_visit_counts_2019']
comp_df['distance_from_home_delta'] = comp_df['distance_from_home_2020'] - comp_df['distance_from_home_2019']
comp_df['raw_visit_counts_delta_pct'] = comp_df['raw_visit_counts_delta'] / comp_df['raw_visit_counts_2019']
comp_df['distance_from_home_delta_pct'] = comp_df['distance_from_home_delta'] / comp_df['distance_from_home_2019']

comp_df.head()
# Out:
#                     safegraph_place_id  raw_visit_counts_2019  \
# 0  sg:465da3a640834193b3167cb8214a7325                  253.0
# 1  sg:c3ab3119ff924f5f8438f8075d61a1dd                  419.0
# 2  sg:a2b62948ca5f4395b86678a216a51190                   52.0
# 3  sg:06a21e9e0fc144a988d669990c3f01f5                  420.0
# 4  sg:170d6d8a39d44f22874af1f35799b89a                 2168.0
#
#    raw_visit_counts_2020  distance_from_home_2019  distance_from_home_2020  \
# 0                  130.0                1370819.0                1125234.0
# 1                  274.0                   7399.0                   8234.0
# 2                   16.0                  12051.0                   6742.0
# 3                  542.0                  18807.0                  18996.0
# 4                  737.0                  10088.0                   5540.0
#
#    raw_visit_counts_delta  distance_from_home_delta  \
# 0                  -123.0                 -245585.0
# 1                  -145.0                     835.0
# 2                   -36.0                   -5309.0
# 3                   122.0                     189.0
# 4                 -1431.0                   -4548.0
#
#    raw_visit_counts_delta_pct  distance_from_home_delta_pct
# 0                   -0.486166                     -0.179152
# 1                   -0.346062                      0.112853
# 2                   -0.692308                     -0.440544
# 3                    0.290476                      0.010049
# 4                   -0.660055                     -0.450833

# %%
comb_df = poi_df.join(comp_df.set_index('safegraph_place_id'), on='sgpid')
comb_df.spatial.set_geometry('SHAPE')

comb_df.head()
# Out:
#                                  sgpid psgpid sgbid  \
# 0  sg:608f9918c8e6432780dba619c4a88c3d   null  null
# 1  sg:94d78ec671b4472dbef6fe4b7945d2b1   null  null
# 2  sg:a16d01fc59234220839ab23c5ae4fdf6   null  null
# 3  sg:afe2a1f4fab740fab57ce21d51e061a9   null  null
# 4  sg:81184956709c489fb4e36e9048e1639e   null  null
#
#                          poiName brands  \
# 0             Healy Heights Park   null
# 1                    Harney Park   null
# 2       Peninsula Crossing Trail   null
# 3                Wellington Park   null
# 4  Bethany Wetlands Natural Area   null
#
#                                               topCat   latitude   longitude  \
# 0  Museums, Historical Sites, and Similar Institu...  45.492833 -122.698466
# 1  Museums, Historical Sites, and Similar Institu...  45.462540 -122.593244
# 2  Museums, Historical Sites, and Similar Institu...  45.593004 -122.726733
# 3  Museums, Historical Sites, and Similar Institu...  45.553219 -122.594489
# 4  Museums, Historical Sites, and Similar Institu...  45.466553 -122.531375
#
#                     address      city  ... zip_code  \
# 0        Healy Heights Park  Portland  ...    97239
# 1               Harney Park  Portland  ...    97206
# 2  Peninsula Crossing Trail  Portland  ...    97203
# 3           Wellington Park  Portland  ...    97218
# 4    Ash Creek Natural Area  Portland  ...    97219
#
#                                                SHAPE raw_visit_counts_2019  \
# 0  {"x": -13658730.7562, "y": 5699444.5308, "spat...                 140.0
# 1  {"x": -13647017.4968, "y": 5694635.255199999, ...                 271.0
# 2  {"x": -13661877.4243, "y": 5715365.990599997, ...                   NaN
# 3  {"x": -13647156.089499999, "y": 5709039.054399...                 186.0
# 4  {"x": -13640130.271200001, "y": 5695272.2051, ...                   NaN
#
#    raw_visit_counts_2020  distance_from_home_2019  distance_from_home_2020  \
# 0                  104.0                   5384.0                   7302.0
# 1                  255.0                   6768.0                   5928.0
# 2                  432.0                      NaN                  11773.0
# 3                  125.0                   7610.0                   1772.0
# 4                  206.0                      NaN                   8190.0
#
#    raw_visit_counts_delta  distance_from_home_delta  \
# 0                   -36.0                    1918.0
# 1                   -16.0                    -840.0
# 2                     NaN                       NaN
# 3                   -61.0                   -5838.0
# 4                     NaN                       NaN
#
#    raw_visit_counts_delta_pct  distance_from_home_delta_pct
# 0                   -0.257143                      0.356241
# 1                   -0.059041                     -0.124113
# 2                         NaN                           NaN
# 3                   -0.327957                     -0.767148
# 4                         NaN                           NaN
#
# [5 rows x 21 columns]

# %%
comb_df.spatial.to_featureclass(gdb_int/'sg_poi_pdx_parks')
# Out:
# 'D:\\projects\\pdx-parks\\data\\interim\\interim.gdb\\sg_poi_pdx_parks'

# %% [markdown]
# # Experimentation Section

# %%
bktd_dwell = fl_df.bucketed_dwell_times.apply(lambda val: pd.Series(json.loads(val)))
bktd_dwell.columns = [f'dwell_{c}'.replace('<', 'under').replace('-', '_').replace('>', 'over') for c in bktd_dwell.columns]
bktd_dwell
# Out:
#      dwell_under5  dwell_5_20  dwell_21_60  dwell_61_240  dwell_over240
# 0               6          74           47            74             25
# 1               1           4            3             1              0
# 2               2          66           38            25             10
# 3               0           6            6            10              6
# 4               9         148          137           154             30
# ..            ...         ...          ...           ...            ...
# 96             18         519          315           433             45
# 97              0          14           15            19              9
# 98              3          29           17            23              9
# 99             17         299          126           145            115
# 100            12         150          117           204             46
#
# [101 rows x 5 columns]

# %%
sum_df = fl_df[['safegraph_place_id', 'location_name', 'raw_visit_counts', 'distance_from_home']]

sum_df.head()
# Out:
#                     safegraph_place_id                location_name  \
# 0  sg:540d0f4bb20d4a5aa25f8e1c4d2e6354         Colonel Summers Park
# 1  sg:fa34d1fd210c4d0187b7b0ce403da09f  Schweitzer Restoration Area
# 2  sg:adf87bec514d4afab326c52cc8bb1570                  Fulton Park
# 3  sg:b80b8720977049b9990b93bb5b782e2b             Shanghai Tunnels
# 4  sg:dc1cea9f581d41d3a3028c4bdbe04110                  Irving Park
#
#    raw_visit_counts  distance_from_home
# 0               226              3532.0
# 1                 9              3181.0
# 2               141             19492.0
# 3                28             11855.0
# 4               478              4016.0

# %%
sum_df.sort_values('raw_visit_counts', ascending=False)
# Out:
#                      safegraph_place_id                       location_name  \
# 15  sg:05cc35de35e0420f95981f919b48437a            Friends of Gateway Green
# 96  sg:f9fab565f35946cb972dcad4f2c4f15f  M James Gleason Memorial Boat Ramp
# 44  sg:9356f1b190a64b47b360dc6123b6acba                    Laurelhurst Park
# 14  sg:b14fded97e3044b8988e3a525e13312b                    Ed Benedict Park
# 87  sg:18977199399744cbb1865464a7c120fd                  Council Crest Park
# ..                                  ...                                 ...
# 49  sg:b47a3ccbcbb747298ee5c3ec6d39d50a      Washington State Horse Council
# 59  sg:dc3b99194af7461bb05e406656f65d55     Glenn L Jackson Memorial Bridge
# 1   sg:fa34d1fd210c4d0187b7b0ce403da09f         Schweitzer Restoration Area
# 65  sg:95befdb52dcc4ad799d18c5db206fb19                 Eastmoreland Garden
# 54  sg:3ba1451020d04eb49d55512d76d1a030                        Moore Island
#
#     raw_visit_counts  distance_from_home
# 15              1452              8979.0
# 96              1330             15177.0
# 44              1272             10861.0
# 14              1048              7295.0
# 87               879              9907.0
# ..               ...                 ...
# 49                16             22999.0
# 59                11              8894.0
# 1                  9              3181.0
# 65                 3                 NaN
# 54                 1                 NaN
#
# [101 rows x 4 columns]

# %%
df_lst = []

for year in pth_df.year.unique():
    
    for month in pth_df.month.unique():
        
        sg_mth_df = pd.concat([pd.read_parquet(f.pth) for idx, f in pth_df[(pth_df.year == year) & (pth_df.month == month)].iterrows()])
        
        for _, sg_r in sg_mth_df.iterrows():
        
            sg_pid = sg_r.safegraph_place_id
            hm_bg_lst = sg_r.visitor_home_cbgs
            
            hc_df = pd.DataFrame.from_dict(json.loads(hm_bg_lst), orient="index", columns=['visitor_home_count'])
            
            hc_df.index.name='block_group_id'
            hc_df.reset_index(inplace=True)
            
            hc_df['sg_id'] = sg_pid
            hc_df['year'] = year
            hc_df['month'] = month
            
            df_lst.append(hc_df)
            
hm_ct_df = pd.concat(df_lst)

hm_ct_df
# Out:
#    block_group_id visitor_home_count                                sg_id  \
# 0    060375433212                  5  sg:465da3a640834193b3167cb8214a7325
# 1    410050225001                  5  sg:465da3a640834193b3167cb8214a7325
# 2    320030029511                  4  sg:465da3a640834193b3167cb8214a7325
# 3    131530211132                  4  sg:465da3a640834193b3167cb8214a7325
# 4    530110417001                  4  sg:465da3a640834193b3167cb8214a7325
# ..            ...                ...                                  ...
# 35   530670113001                  4  sg:ff6f7c7e3e1b4ac9876261b221fe7f83
# 36   530150016003                  4  sg:ff6f7c7e3e1b4ac9876261b221fe7f83
# 37   410510040022                  4  sg:ff6f7c7e3e1b4ac9876261b221fe7f83
# 38   410050229061                  4  sg:ff6f7c7e3e1b4ac9876261b221fe7f83
# 39   410510040023                  4  sg:ff6f7c7e3e1b4ac9876261b221fe7f83
#
#     year  month
# 0   2019      6
# 1   2019      6
# 2   2019      6
# 3   2019      6
# 4   2019      6
# ..   ...    ...
# 35  2020      8
# 36  2020      8
# 37  2020      8
# 38  2020      8
# 39  2020      8
#
# [52430 rows x 5 columns]

# %%
hm_ct_df.to_parquet(dir_int/'hm_cnt.parquet')
