# %%
import pandas as pd
from pathlib import Path

# from dm import Country

# %%
dir_prj = Path.cwd().parent

dir_data = dir_prj/'data'

dir_raw = dir_data/'raw'
dir_int = dir_data/'interim'

gdb_raw = dir_raw/'raw.geodatabase'
gdb_int = dir_int/'interim.geodatabase'

# %%
nrml_pth = r"D:\projects\safegraph-data-utilities\data\raw\normalization_stats.parquet"

# %%
nrml_df = pd.read_parquet(nrml_pth)
nrml_df
# Out:
#       year  month  day      region  total_visits  total_devices_seen  \
# 0     2020      7    1  ALL_STATES      49244626            15948187
# 1     2020      7    1          ak         65639               21950
# 2     2020      7    1          al       1278652              385820
# 3     2020      7    1          ar        662994              203241
# 4     2020      7    1          as            19                  18
# ...    ...    ...  ...         ...           ...                 ...
# 1762  2020      7   31          vt         57616               22868
# 1763  2020      7   31          wa        878952              314411
# 1764  2020      7   31          wi        922265              314755
# 1765  2020      7   31          wv        281836              100551
# 1766  2020      7   31          wy         91415               32769
#
#       total_home_visits  total_home_visitors
# 0              22155114             13151034
# 1                 26164                16785
# ...
